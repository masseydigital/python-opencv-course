# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB ---->  RED,GREEN,BLUE
# OPENCV -------->  BLUE,GREEN,RED

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img, (1000, 400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8
h_ratio = 0.2 # 20% of original height

# %%
ratio_img = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(ratio_img)

# %%
ratio_img.shape
# Out:
# (260, 1560, 3)

# %%
flip_img = cv2.flip(fix_img, 1)

# %%
plt.imshow(flip_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
